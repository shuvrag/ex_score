# %%
# Importing libraries
import pandas as pd
import numpy as np

# Removing width limit
pd.options.display.max_columns = None

# Removing other limits
#pd.set_option('display.max_rows', 500)
#pd.set_option('display.max_columns', 500)
#pd.set_option('display.width', 1000)

from IPython.display import display

import matplotlib.pyplot as plt
# %matplotlib inline

# Not used below
from scipy import stats
from sklearn import preprocessing
from sklearn.model_selection import KFold
from sklearn.linear_model import LinearRegression

# %%
#Choosing data frame
path = 'calc1_f18.csv'
exam_data = pd.read_csv(path)

#Preprocess by filling in 0's for NaN's (blanks)
#df.fillna({"Homework_1":0}, inplace=True)
exam_data.fillna(0, inplace=True)

# Displaying data
exam_data.head()
#display(exam_data)

#exam_data.drop(["Homework-1"], axis = 1, inplace=True)
#np.mean(exam_data["Final_Exam"])
# Out:
#    Homework_1  Homework_2  Homework_3  Homework_4  Homework_5  Homework_6  \
# 0       15.00       15.00        15.0        15.0        15.0        15.0
# 1       15.00       15.00        15.0        15.0        15.0        15.0
# 2       15.00       15.00        15.0        15.0        15.0        15.0
# 3       14.78       15.00        15.0        15.0        15.0        15.0
# 4       15.00       14.86        15.0        15.0        15.0        15.0
#
#    Homework_7  Homework_8  Homework_9  Homework_10  Homework_11  Homework_12  \
# 0        15.0        15.0       15.00        15.00         15.0        15.00
# 1        15.0         0.0       15.00        15.00         15.0        14.00
# 2        15.0        15.0       15.00        15.00         15.0        15.00
# 3        15.0        15.0       15.00        15.00         15.0        13.75
# 4        15.0        15.0       14.88        14.88         15.0        15.00
#
#    Homework_13  Homework_14  Quiz_2  Quiz_3  Quiz_4  Quiz_5  Quiz_6  Quiz_7  \
# 0         15.0          3.0    10.0    10.0     7.0    10.0    10.0    10.0
# 1         15.0         14.0    10.0     9.0     8.0    10.0    10.0    10.0
# 2         15.0         15.0    10.0    10.0    10.0    10.0    10.0    10.0
# 3         15.0         15.0    10.0     9.0     8.0    10.0    10.0    10.0
# 4         15.0         15.0    10.0    10.0    10.0    10.0    10.0    10.0
#
#    Quiz_8  Quiz_9  Quiz_10  Quiz_11  Exam_1  Exam_2  Exam_3  Final_Exam
# 0     9.0     9.0     10.0     10.0    54.0    46.0    60.0        70.0
# 1    10.0    10.0     10.0      8.0    58.0    51.0    59.0        70.0
# 2    10.0    10.0     10.0     10.0    59.0    53.0    51.0        70.0
# 3    10.0    10.0     10.0     10.0    52.0    51.0    47.0        70.0
# 4    10.0    10.0     10.0     10.0    52.0    55.0    45.0        70.0

# %%
#plt.hist(exam_data['Exam_1'])

# %%
# Scatter plots
x = exam_data['Homework_1']
y = exam_data['Final_Exam']
colors = (0,0,0)
area = np.pi*3
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.title('Final_Exam vs Homework_1')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
# Scatter plots
x = exam_data['Homework_14']
y = exam_data['Final_Exam']
colors = (0,0,0)
area = np.pi*3
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.title('Final_Exam vs Homework_14')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
# Scatter plots
x = exam_data['Quiz_2']
y = exam_data['Final_Exam']
colors = (0,0,0)
area = np.pi*3
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.title('Final_Exam vs Quiz_2')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
# Scatter plots
x = exam_data['Quiz_11']
y = exam_data['Final_Exam']
colors = (0,0,0)
area = np.pi*3
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.title('Final_Exam vs Quiz_11')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
# Scatter plots
x = exam_data['Exam_1']
y = exam_data['Final_Exam']
colors = (0,0,0)
area = np.pi*3
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.title('Final_Exam vs Exam_1')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
# Scatter plots
x = exam_data['Exam_2']
y = exam_data['Final_Exam']
colors = (0,0,0)
area = np.pi*3
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.title('Final_Exam vs Exam_2')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
# Scatter plots
x = exam_data['Exam_3']
y = exam_data['Final_Exam']
colors = (0,0,0)
area = np.pi*3
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.title('Final_Exam vs Exam_3')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
# Make HW, Quiz and Exam1-3 avgs
hw = exam_data.loc[: , 'Homework_1':'Homework_14']
exam_data['HW_Mean'] = hw.mean(axis = 1)

qz = exam_data.loc[: , 'Quiz_2':'Quiz_11']
exam_data['Quiz_Mean'] = qz.mean(axis = 1)

ex = exam_data.loc[: , 'Exam_1':'Exam_3']
exam_data['Exam_Mean'] = ex.mean(axis = 1)

exam_data.describe()
#exam_data.head()
# Out:
#         Homework_1   Homework_2   Homework_3   Homework_4   Homework_5  \
# count  1177.000000  1177.000000  1177.000000  1177.000000  1177.000000
# mean     13.304087    13.489550    13.220263    12.820467    12.408003
# std       4.032792     3.694604     3.976100     4.208060     4.476362
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%      14.000000    14.000000    13.900000    13.170000    12.500000
# 50%      15.000000    15.000000    15.000000    14.720000    14.500000
# 75%      15.000000    15.000000    15.000000    15.000000    15.000000
# max      15.000000    15.000000    15.000000    15.000000    15.000000
#
#         Homework_6   Homework_7   Homework_8   Homework_9  Homework_10  \
# count  1177.000000  1177.000000  1177.000000  1177.000000  1177.000000
# mean     13.115913    11.968097    11.253067    11.795930    11.440561
# std       4.138473     5.044803     4.979812     4.882778     5.151634
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%      13.830000    12.200000     9.750000    11.000000    10.710000
# 50%      15.000000    14.500000    13.630000    14.330000    14.000000
# 75%      15.000000    15.000000    15.000000    15.000000    15.000000
# max      15.000000    15.000000    15.000000    15.000000    15.000000
#
#        Homework_11  Homework_12  Homework_13  Homework_14       Quiz_2  \
# count  1177.000000  1177.000000  1177.000000  1177.000000  1177.000000
# mean     10.558564     9.998369    10.169932     7.400994     7.073067
# std       5.631913     6.059922     6.283020     6.941847     2.894358
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       6.930000     3.000000     2.500000     0.000000     5.000000
# 50%      13.670000    13.500000    14.000000     8.000000     8.000000
# 75%      15.000000    15.000000    15.000000    15.000000    10.000000
# max      15.000000    15.000000    15.000000    15.000000    10.000000
#
#             Quiz_3       Quiz_4       Quiz_5       Quiz_6       Quiz_7  \
# count  1177.000000  1177.000000  1177.000000  1177.000000  1177.000000
# mean      6.646559     7.185217     7.862362     7.283772     6.856415
# std       3.036760     2.989156     2.773432     2.988743     3.085617
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       5.000000     5.000000     7.000000     6.000000     5.000000
# 50%       7.000000     8.000000     9.000000     8.000000     8.000000
# 75%       9.000000    10.000000    10.000000    10.000000    10.000000
# max      10.000000    10.000000    11.000000    10.000000    10.000000
#
#             Quiz_8       Quiz_9      Quiz_10      Quiz_11       Exam_1  \
# count  1177.000000  1177.000000  1177.000000  1177.000000  1177.000000
# mean      7.513169     6.685641     6.189465     7.360238    33.785896
# std       2.956034     3.111544     3.427176     3.476752    13.813507
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       6.000000     5.000000     4.000000     6.000000    24.000000
# 50%       9.000000     8.000000     7.000000     9.000000    35.000000
# 75%      10.000000     9.000000     9.000000    10.000000    44.000000
# max      10.000000    10.000000    10.000000    10.000000    59.000000
#
#             Exam_2       Exam_3   Final_Exam      HW_Mean    Quiz_Mean  \
# count  1177.000000  1177.000000  1177.000000  1177.000000  1177.000000
# mean     26.907392    24.414613    33.501274    11.638843     7.065590
# std      13.643197    13.777992    19.015842     3.497687     2.127731
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%      17.000000    14.000000    20.000000    10.462857     6.100000
# 50%      27.000000    25.000000    34.000000    12.770000     7.600000
# 75%      37.000000    34.000000    49.000000    14.111429     8.600000
# max      60.000000    60.000000    70.000000    15.000000    10.000000
#
#          Exam_Mean
# count  1177.000000
# mean     28.369300
# std      12.496543
# min       0.000000
# 25%      19.666667
# 50%      29.000000
# 75%      37.666667
# max      59.000000

# %%
# Scatter plots
#x = exam_data['Homework_1']
#x = exam_data['Homework_14']
#x = exam_data['Quiz_2']
#x = exam_data['Quiz_11']
#x = exam_data['Exam_1']
#x = exam_data['Exam_2']
#x = exam_data['Exam_3']
#x = exam_data['HW_Mean']
#x = exam_data['Quiz_Mean']
x = exam_data['Exam_Mean']
y = exam_data['Final_Exam']
colors = (0,0,0)
area = np.pi*3
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.title('Final Exam vs x')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
exam_data.hist()

#df = exam_data
#df = pd.DataFrame(np.random.randn(3100)
#                  .reshape((100, 31)), columns=['col_{}'.format(i) for i in range(31)])
#df.hist(alpha=0.5, figsize=(20, 10))
#plt.tight_layout()
#plt.show()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000023FC6AFD6A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023FC6AF2C18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023FC6BCC3C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023FC6B0E978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023FC6A17F28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023FC6AC4518>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000023FC6B4AAC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023FC6A5E0F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023FC6A5E128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023FC6C28BE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023FC6C671D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023FC6C97780>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000023FC6CC8D30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023FC6D07320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023FC6D388D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023FC6D6CE80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023FC6DA9470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023FC6DDAA20>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000023FC6E0CFD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023FC6E4A5C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023FC6E7AB70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023FC6EB8160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023FC6EE7710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023FC6F1BCC0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000023FC6F5A2B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023FC6F89860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023FC6FBCE10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023FC6FFA400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023FC702B9B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023FC705EF60>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000023FC709B550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023FC70CDB00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023FC710A0F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023FC713E6A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023FC716EC50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023FC71AD240>]],
#       dtype=object)

# %%
plt.hist(exam_data['Final_Exam'])
# Out:
# (array([135.,  70., 115., 111., 158., 163., 127., 120., 114.,  64.]),
#  array([ 0.,  7., 14., 21., 28., 35., 42., 49., 56., 63., 70.]),
#  <a list of 10 Patch objects>)

# %%
# Linear Model using scikitlearn
from sklearn import linear_model as lm

X = exam_data[["Exam_Mean"]]
y= exam_data["Final_Exam"]

# Fit the linear model
linear_model = lm.LinearRegression()
results = linear_model.fit(X,y)

# Print the coeffecients
print (linear_model.intercept_, linear_model.coef_)

# RMS Error Calculation
#N = len(y)
#rmse_test = np.sqrt(np.sum((np.array(y).flatten() - np.array(results).flatten())**2)/N)
#print("RMSE TEST: ", rmse_test)

#from sklearn.metrics import mean_squared_error
#from math import sqrt

#rms = sqrt(mean_squared_error(y, results))
# Out:
# -3.203985690572651 [1.29383733]

# %%
# Linear Model using Statsmodels
import statsmodels.api as sm

X = sm.add_constant(X)

# Fit the linear model
linear_model_2 = sm.OLS(y, X).fit()
#predictions = linear_model.predict(X)

# Print the regression results
linear_model_2.summary()
# Out:
# 10.00484671671277

# %%
import seaborn as sns
sns.regplot(x='Final_Exam', y='Exam_Mean', data=exam_data)

# %%
X = exam_data[["HW_Mean","Quiz_Mean","Exam_Mean"]]
y= exam_data["Final_Exam"]

linear_model = lm.LinearRegression()
results = linear_model.fit(X,y)

print (linear_model.intercept_, linear_model.coef_)
# Out:
# -9.277429314824722 [0.16051946 1.38325456 1.0975573 ]

# %%
X = sm.add_constant(X)

linear_model_2 = sm.OLS(y, X).fit()

linear_model_2.summary()
# Out:
# C:\Users\shuvr\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Final_Exam   R-squared:                       0.737
# Model:                            OLS   Adj. R-squared:                  0.737
# Method:                 Least Squares   F-statistic:                     1097.
# Date:                Fri, 20 Dec 2019   Prob (F-statistic):               0.00
# Time:                        14:55:02   Log-Likelihood:                -4349.8
# No. Observations:                1177   AIC:                             8708.
# Df Residuals:                    1173   BIC:                             8728.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -9.2774      1.078     -8.603      0.000     -11.393      -7.162
# HW_Mean        0.1605      0.109      1.478      0.140      -0.053       0.374
# Quiz_Mean      1.3833      0.237      5.844      0.000       0.919       1.848
# Exam_Mean      1.0976      0.034     32.124      0.000       1.031       1.165
# ==============================================================================
# Omnibus:                        2.693   Durbin-Watson:                   0.928
# Prob(Omnibus):                  0.260   Jarque-Bera (JB):                2.756
# Skew:                          -0.051   Prob(JB):                        0.252
# Kurtosis:                       3.214   Cond. No.                         129.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# Partial Regression Plots
#In [20]: sm.graphics.plot_partregress('Final_Exam', 'Exam_3', ['Exam_2', 'Exam_1'], data=exam_data, obs_labels=False)

# %%
y = exam_data.Final_Exam

#features = ['HW_Mean', 'Quiz_Mean', 'Exam_Mean']
features = ['Homework_1', 'Homework_2', 'Homework_3', 'Homework_4', 'Homework_5', 'Homework_6', 'Homework_7', 'Homework_8',
            'Homework_9', 'Homework_10', 'Homework_11', 'Homework_12', 'Homework_13', 'Homework_14', 'Quiz_2', 'Quiz_3',
            'Quiz_4', 'Quiz_5', 'Quiz_6', 'Quiz_7', 'Quiz_8', 'Quiz_9', 'Quiz_10', 'Quiz_11', 'Exam_1', 'Exam_2', 'Exam_3']
X = exam_data[features]

#X.describe()
#X.head()

# %%
from sklearn.model_selection import train_test_split as tts

# Split data into training and validation data
train_X, val_X, train_y, val_y = tts(X, y, random_state = 1)

# %%
train_X.describe()
# Out:
#        Homework_1  Homework_2  Homework_3  Homework_4  Homework_5  Homework_6  \
# count  882.000000  882.000000  882.000000  882.000000  882.000000  882.000000
# mean    13.244195   13.456916   13.186190   12.794717   12.349195   12.968662
# std      4.116437    3.754156    4.046263    4.244888    4.553614    4.339052
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%     14.000000   14.000000   14.000000   13.110000   12.462500   13.750000
# 50%     15.000000   15.000000   15.000000   14.720000   14.500000   15.000000
# 75%     15.000000   15.000000   15.000000   15.000000   15.000000   15.000000
# max     15.000000   15.000000   15.000000   15.000000   15.000000   15.000000
#
#        Homework_7  Homework_8  Homework_9  Homework_10  Homework_11  \
# count  882.000000  882.000000  882.000000   882.000000   882.000000
# mean    11.817404   11.062313   11.762222    11.360544    10.412971
# std      5.165529    5.136430    4.944601     5.280655     5.734641
# min      0.000000    0.000000    0.000000     0.000000     0.000000
# 25%     11.600000    9.232500   10.970000    10.750000     6.000000
# 50%     14.500000   13.550000   14.330000    14.080000    13.670000
# 75%     15.000000   15.000000   15.000000    15.000000    15.000000
# max     15.000000   15.000000   15.000000    15.000000    15.000000
#
#        Homework_12  Homework_13  Homework_14      Quiz_2      Quiz_3  \
# count   882.000000   882.000000   882.000000  882.000000  882.000000
# mean      9.938084    10.091519     7.400329    7.039683    6.623583
# std       6.150717     6.305365     6.943259    2.962806    3.088375
# min       0.000000     0.000000     0.000000    0.000000    0.000000
# 25%       2.062500     2.562500     0.000000    5.000000    4.000000
# 50%      13.500000    14.000000     7.670000    8.000000    7.000000
# 75%      15.000000    15.000000    15.000000   10.000000    9.000000
# max      15.000000    15.000000    15.000000   10.000000   10.000000
#
#            Quiz_4      Quiz_5      Quiz_6      Quiz_7      Quiz_8      Quiz_9  \
# count  882.000000  882.000000  882.000000  882.000000  882.000000  882.000000
# mean     7.090703    7.789116    7.237528    6.867347    7.429705    6.664399
# std      3.031942    2.859712    3.024585    3.116264    3.056439    3.139703
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      5.000000    7.000000    6.000000    5.000000    6.000000    5.000000
# 50%      8.000000    9.000000    8.000000    8.000000    9.000000    8.000000
# 75%     10.000000   10.000000   10.000000   10.000000   10.000000    9.000000
# max     10.000000   11.000000   10.000000   10.000000   10.000000   10.000000
#
#           Quiz_10     Quiz_11      Exam_1      Exam_2      Exam_3
# count  882.000000  882.000000  882.000000  882.000000  882.000000
# mean     6.108844    7.221088   33.600907   26.831066   24.292517
# std      3.491119    3.589600   14.021854   13.840252   14.058598
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      4.000000    6.000000   24.000000   17.000000   14.000000
# 50%      7.000000    9.000000   35.000000   27.000000   24.000000
# 75%      9.000000   10.000000   44.000000   37.000000   34.000000
# max     10.000000   10.000000   59.000000   60.000000   60.000000

# %%
val_X.describe()
# Out:
#        Homework_1  Homework_2  Homework_3  Homework_4  Homework_5  Homework_6  \
# count  295.000000  295.000000  295.000000  295.000000  295.000000  295.000000
# mean    13.483153   13.587119   13.322136   12.897458   12.583831   13.556169
# std      3.772689    3.514901    3.763315    4.102096    4.239599    3.439509
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%     14.000000   14.000000   13.710000   13.455000   12.710000   14.000000
# 50%     15.000000   15.000000   15.000000   14.720000   14.500000   15.000000
# 75%     15.000000   15.000000   15.000000   15.000000   15.000000   15.000000
# max     15.000000   15.000000   15.000000   15.000000   15.000000   15.000000
#
#        Homework_7  Homework_8  Homework_9  Homework_10  Homework_11  \
# count  295.000000  295.000000  295.000000   295.000000   295.000000
# mean    12.418644   11.823390   11.896712    11.679797    10.993864
# std      4.644462    4.438422    4.699830     4.745481     5.298451
# min      0.000000    0.000000    0.000000     0.000000     0.000000
# 25%     12.825000   10.550000   11.035000    10.545000     8.140000
# 50%     14.500000   13.750000   14.360000    13.960000    13.860000
# 75%     15.000000   15.000000   15.000000    15.000000    15.000000
# max     15.000000   15.000000   15.000000    15.000000    15.000000
#
#        Homework_12  Homework_13  Homework_14      Quiz_2      Quiz_3  \
# count   295.000000   295.000000   295.000000  295.000000  295.000000
# mean     10.178610    10.404373     7.402983    7.172881    6.715254
# std       5.786349     6.220460     6.949417    2.681622    2.880902
# min       0.000000     0.000000     0.000000    0.000000    0.000000
# 25%       6.000000     2.500000     0.000000    5.000000    5.000000
# 50%      13.170000    14.000000     8.670000    8.000000    7.000000
# 75%      15.000000    15.000000    15.000000   10.000000   10.000000
# max      15.000000    15.000000    15.000000   10.000000   10.000000
#
#            Quiz_4      Quiz_5      Quiz_6      Quiz_7      Quiz_8      Quiz_9  \
# count  295.000000  295.000000  295.000000  295.000000  295.000000  295.000000
# mean     7.467797    8.081356    7.422034    6.823729    7.762712    6.749153
# std      2.843685    2.489466    2.879500    2.997070    2.622113    3.030142
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      6.000000    7.000000    6.000000    5.000000    7.000000    5.000000
# 50%      8.000000    9.000000    8.000000    8.000000    9.000000    8.000000
# 75%     10.000000   10.000000   10.000000   10.000000   10.000000    9.000000
# max     10.000000   10.000000   10.000000   10.000000   10.000000   10.000000
#
#           Quiz_10     Quiz_11      Exam_1      Exam_2      Exam_3
# count  295.000000  295.000000  295.000000  295.000000  295.000000
# mean     6.430508    7.776271   34.338983   27.135593   24.779661
# std      3.222120    3.083439   13.178536   13.056468   12.918725
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      4.500000    7.000000   24.000000   17.500000   15.000000
# 50%      7.000000    9.000000   36.000000   26.000000   25.000000
# 75%      9.000000   10.000000   45.000000   37.000000   34.000000
# max     10.000000   10.000000   59.000000   60.000000   58.000000

# %%
from sklearn.tree import DecisionTreeRegressor as dtr

# Fit Decision Tree Model
exam_model = dtr(random_state = 1)
exam_model.fit(train_X,train_y)

# Predict using DTM
from sklearn.metrics import mean_absolute_error as mae
val_fin = exam_model.predict(val_X)

# Display MAE
print(mae(val_y, val_fin))
# Out:
# 11.694915254237289

# %%
# Write subroutine to return mae
#def get_mae(max_leaf_nodes, train_X, val_X, train_y, val_y):
#    model = dtr(max_leaf_nodes=max_leaf_nodes, random_state=1)
#    model.fit(train_X, train_y)
#    val_fin = exam_model.predict(val_X)
#    ret_mae = mae(val_y, val_fin)
#    return(ret_mae)

# Find best fit (balance between underfitting and overfitting)
#for max_leaf_nodes in [2, 5, 50, 500, 5000]:
#    my_mae = get_mae(max_leaf_nodes, train_X, val_X, train_y, val_y)
#    print("Max leaf nodes: %d  \t\t Mean Absolute Error:  %d" %(max_leaf_nodes, my_mae))
    
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

# Fit Random Forest Model
forest_model = RandomForestRegressor(random_state=1)
forest_model.fit(train_X, train_y)

# Predict using RFM
melb_preds = forest_model.predict(val_X)

# Display MAE
print(mean_absolute_error(val_y, melb_preds))
# Out:
# 8.448813559322033
# C:\Users\shuvr\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
# Now build a Neural Network, using TensorFlow
# See how predictions compare
